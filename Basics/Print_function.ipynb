# %% [markdown]
# <a href="https://colab.research.google.com/github/Akansha051991/Python-Journey/blob/main/Basics/Print_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(6.8)
# Out:
# 6.8

# %%
print(False)
# Out:
# False

# %%
#to print multiple values
print("India", "Nepal", "Bhutan")
# Out:
# India Nepal Bhutan

# %%
print("India", 5, True)
# Out:
# India 5 True

# %%
# to print using a seperator
print("India", "Nepal", "Bhutan", sep='/')
# Out:
# India/Nepal/Bhutan

# %%
print("India", "Nepal", "Bhutan", sep='-')
# Out:
# India-Nepal-Bhutan

# %%
# to print in same line
print("Hello", end= ' ')
print("World")
# Out:
# Hello World
